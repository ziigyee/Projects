# %%
import pandas as pd

# %%
df = pd.read_pickle('jobstreet_pickle')

# %%
df
# Out:
#                                                Company  \
# 0                             Career Edge Asia Pte Ltd
# 1                                          YGP Pte Ltd
# 2                                                 None
# 3                               nSearch Global Pte Ltd
# 4                            Adecco Personnel Pte Ltd.
# 5                                   (Recruitment Firm)
# 6                              RECRUIT EXPRESS PTE LTD
# 7                            Sopra Steria Asia Pte Ltd
# 8                   United Overseas Bank Limited (UOB)
# 9                   United Overseas Bank Limited (UOB)
# 10                                    DBS Bank Limited
# 11                  United Overseas Bank Limited (UOB)
# 12                  United Overseas Bank Limited (UOB)
# 13                                         StarHub Ltd
# 14                                  (Recruitment Firm)
# 15                                  (Recruitment Firm)
# ...
